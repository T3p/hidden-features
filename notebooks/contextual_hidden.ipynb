# %% [markdown]
# # Contextual Linear Bandit with Hidden Features

# %% [markdown]
# * N. contexts: 10
# * N. actions: 3
# * Hidden/features: 1/10
# * lambda: 0.1
# * noise std: 0.1
# * offset scale d = 1
# * magnitude bounds all 1

# %%
import nu
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'nu' from '/home/matteo/notebook-utils/nu.py'>

# %%
nu.setdir('../results')

# %%
nu.compare_student(['oful.1.103', 'hoful.1.103', 'oracle'], key='cumpseudoregret')
# Out:
# oful.1.103: aggregating 10 runs
# hoful.1.103: aggregating 10 runs
# oracle: aggregating 10 runs

# %%
nu.compare_student(['oful.1.103', 'hoful.1.103', 'oracle'], key='paramerror')
# Out:
# oful.1.103: aggregating 10 runs
# hoful.1.103: aggregating 10 runs
# oracle: aggregating 10 runs

# %%
nu.compare_student(['hoful.1.103'], key='offseterror')
# Out:
# hoful.1.103: aggregating 10 runs

# %% [markdown]
# ### Changing the number of hidden features

# %%
nu.compare_student(['hoful.1.103', 'hoful.2', 'hoful.3', 'hoful.4'
                   , 'hoful.5', 'hoful.6', 'hoful.7', 'hoful.8'
                   , 'hoful.9' , 'hoful.10'], key='cumpseudoregret')
# Out:
# hoful.1.103: aggregating 10 runs
# hoful.2: aggregating 10 runs
# hoful.3: aggregating 10 runs
# hoful.4: aggregating 10 runs
# hoful.5: aggregating 10 runs
# hoful.6: aggregating 10 runs
# hoful.7: aggregating 10 runs
# hoful.8: aggregating 10 runs
# hoful.9: aggregating 10 runs
# hoful.10: aggregating 10 runs

# %% [markdown]
# ### Same on larger problem

# %% [markdown]
# 10 contexts, 10 arms, 10 total features

# %%
nu.compare_student(['hoful.1.1010', 'hoful.25.1010', 'hoful.50.1010', 'hoful.75.1010'
                   , 'hoful.100.1010'], key='cumpseudoregret')
# Out:
# hoful.1.1010: aggregating 10 runs
# hoful.25.1010: aggregating 10 runs
# hoful.50.1010: aggregating 10 runs
# hoful.75.1010: aggregating 10 runs
# hoful.100.1010: aggregating 10 runs

# %% [markdown]
# ### More contexts and actions

# %%
nu.compare_student(['oful.1.10010', 'hoful.1.10010'], key='cumpseudoregret')
# Out:
# oful.1.10010: aggregating 10 runs
# hoful.1.10010: aggregating 10 runs
