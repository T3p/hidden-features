# %% [markdown]
# # Contextual Linear Bandit with Hidden Features

# %%
import nu
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'nu' from '/home/matteo/notebook-utils/nu.py'>

# %%
nu.setdir('../results')

# %%
nu.compare_student(['oracle', 'oful', 'hoful', 'ihoful', 'offsetx'], key='cumregret')
# Out:
# oracle: aggregating 10 runs
# oful: aggregating 10 runs
# hoful: aggregating 10 runs
# ihoful: aggregating 10 runs
# offsetx: aggregating 10 runs

# %%
nu.compare_student(['oracle', 'oful', 'hoful', 'ihoful'], key='paramerror')
# Out:
# oracle: aggregating 10 runs
# oful: aggregating 10 runs
# hoful: aggregating 10 runs
# ihoful: aggregating 10 runs

# %%
nu.compare_student(['oracle', 'oful', 'hoful', 'ihoful'], key='featerror')
# Out:
# oracle: aggregating 10 runs
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'featerror'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-3250a5729765> in <module>
# ...

# %%
nu.compare_student(['ucb', 'offset', 'offsetx'], key='cumregret')
# Out:
# ucb: aggregating 10 runs
# offset: aggregating 10 runs
# offsetx: aggregating 10 runs
