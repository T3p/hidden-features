# %% [markdown]
# # Contextual Linear Bandit with Hidden Features

# %% [markdown]
# * N. contexts: 10
# * N. actions: 3
# * Hidden/features: 1/10
# * lambda: 0.1
# * noise std: 0.1
# * offset scale d = 1
# * magnitude bounds all 1

# %%
import nu
from importlib import reload

# %%
reload(nu)
# Out:
# <module 'nu' from '/home/matteo/notebook-utils/nu.py'>

# %%
nu.setdir('../results')

# %%
nu.compare_student(['oful', 'hoful', 'oracle'], key='cumpseudoregret')
# Out:
# oful: aggregating 10 runs
# hoful: aggregating 10 runs
# oracle: aggregating 10 runs

# %%
nu.compare_student(['oful', 'hoful', 'oracle'], key='paramerror')
# Out:
# oful: aggregating 10 runs
# hoful: aggregating 10 runs
# oracle: aggregating 10 runs

# %%
nu.compare_student(['hoful'], key='offseterror')
# Out:
# hoful: aggregating 10 runs
